# %%
import numpy as np
import pandas as pd
x_test=pd.read_csv('input_test.csv');
x_train=pd.read_csv('input_training.csv');
y_train=pd.read_csv('output_training.csv');
#print(x_train)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 15 columns):
# ID                         8760 non-null int64
# timestamp                  8760 non-null object
# temp_1                     8589 non-null float64
# temp_2                     8429 non-null float64
# mean_national_temp         8760 non-null float64
# humidity_1                 8589 non-null float64
# humidity_2                 8428 non-null float64
# loc_1                      8760 non-null object
# loc_2                      8760 non-null object
# loc_secondary_1            8760 non-null object
# loc_secondary_2            8760 non-null object
# loc_secondary_3            8760 non-null object
# consumption_secondary_1    8760 non-null int64
# consumption_secondary_2    8760 non-null int64
# consumption_secondary_3    8760 non-null int64
# dtypes: float64(5), int64(4), object(6)
# memory usage: 1.0+ MB

# %%
x_train.boxplot(column=['temp_1','temp_2','mean_national_temp','humidity_1','humidity_2','consumption_secondary_1','consumption_secondary_2','consumption_secondary_3'],figsize=(20,8))

# %%
x_train.boxplot('consumption_secondary_1')

# %%
x_train.isnull().sum()
# Out:
# ID                           0
# timestamp                    0
# temp_1                     171
# temp_2                     331
# mean_national_temp           0
# humidity_1                 171
# humidity_2                 332
# loc_1                        0
# loc_2                        0
# loc_secondary_1              0
# loc_secondary_2              0
# loc_secondary_3              0
# consumption_secondary_1      0
# consumption_secondary_2      0
# consumption_secondary_3      0
# dtype: int64

# %%
x_test.isnull().sum()
# Out:
# ID                           0
# timestamp                    0
# temp_1                      34
# temp_2                     243
# mean_national_temp           0
# humidity_1                  34
# humidity_2                 243
# loc_1                        0
# loc_2                        0
# loc_secondary_1              0
# loc_secondary_2              0
# loc_secondary_3              0
# consumption_secondary_1      0
# consumption_secondary_2      0
# consumption_secondary_3      0
# dtype: int64

# %%
x_train=x_train.drop('ID',axis=1)
x_train=x_train.drop('timestamp',axis=1)

# %%
x_train.plot(figsize=(10,10))

# %%
mt1=x_train.temp_1.median()
x_train.temp_1=x_train.temp_1.fillna(mt1)
mt2=x_train.temp_2.median()
x_train.temp_2=x_train.temp_2.fillna(mt2)
mh1=x_train.humidity_1.median()
x_train.humidity_1=x_train.humidity_1.fillna(mh1)
mh2=x_train.humidity_2.median()
x_train.humidity_2=x_train.humidity_2.fillna(mh2)

# %%
x_train.isnull().sum()
# Out:
# temp_1                     0
# temp_2                     0
# mean_national_temp         0
# humidity_1                 0
# humidity_2                 0
# loc_1                      0
# loc_2                      0
# loc_secondary_1            0
# loc_secondary_2            0
# loc_secondary_3            0
# consumption_secondary_1    0
# consumption_secondary_2    0
# consumption_secondary_3    0
# dtype: int64

# %%
#print(y_train)

# %%
x_train=x_train.drop('loc_1',axis=1)
x_train=x_train.drop('loc_2',axis=1)
x_train=x_train.drop('loc_secondary_1',axis=1)
x_train=x_train.drop('loc_secondary_2',axis=1)
x_train=x_train.drop('loc_secondary_3',axis=1)

# %%
#x_train['loc_1'] = x_train['loc_1'].apply(lambda x: 1)
#x_train['loc_2'] = x_train['loc_2'].apply(lambda x: 2)

# %%
x_train.isnull().sum()
# Out:
# temp_1                     0
# temp_2                     0
# mean_national_temp         0
# humidity_1                 0
# humidity_2                 0
# consumption_secondary_1    0
# consumption_secondary_2    0
# consumption_secondary_3    0
# dtype: int64

# %%
x_test=x_test.drop('ID',axis=1)
x_test=x_test.drop('timestamp',axis=1)
x_test=x_test.drop('loc_1',axis=1)
x_test=x_test.drop('loc_2',axis=1)
#x_test['loc_1'] = x_test['loc_1'].apply(lambda x: 1)
#x_test['loc_2'] = x_test['loc_2'].apply(lambda x: 2)
x_test=x_test.drop('loc_secondary_1',axis=1)
x_test=x_test.drop('loc_secondary_2',axis=1)
x_test=x_test.drop('loc_secondary_3',axis=1)

# %%
y_train=y_train.drop('ID',axis=1)
#y_train.info

# %%
x_train_1=x_train.drop(['temp_2','humidity_2'],axis=1)
x_train_2=x_train.drop(['temp_1','humidity_1'],axis=1)
y_train_1=y_train.drop('consumption_2',axis=1)
y_train_2=y_train.drop('consumption_1',axis=1)

# %%
data=pd.concat([x_train,y_train],axis=1,sort=False)
#data.info()

# %%
data.plot(figsize=(9,9))

# %%
data.plot.scatter(x='consumption_1',y='consumption_secondary_1')

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data,alpha=0.2,figsize=(12,12),diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024ABB8D29E8>,
# ...
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split
train_x_train, test_x_train = train_test_split(data, test_size=0.1)

# %%
x_train_x_train= train_x_train.drop(['consumption_1','consumption_2'],axis=1)

# %%
y_train_x_train=train_x_train.iloc[:,8:10]

# %%
x_train_x_train_1=x_train_x_train.drop(['temp_2','humidity_2'],axis=1)
x_train_x_train_2=x_train_x_train.drop(['temp_1','humidity_1'],axis=1)
y_train_x_train_1=y_train_x_train.iloc[:,0]
y_train_x_train_2=y_train_x_train.iloc[:,1]

# %%
x_test_x_train= test_x_train.drop(['consumption_1','consumption_2'],axis=1)
y_test_x_train=test_x_train.iloc[:,8:10]
x_test_x_train_1=x_test_x_train.drop(['temp_2','humidity_2'],axis=1)
x_test_x_train_2=x_test_x_train.drop(['temp_2','humidity_2'],axis=1)
y_test_x_train_1=y_test_x_train.iloc[:,0]
y_test_x_train_2=y_test_x_train.iloc[:,1]

# %%
#print(y_train_x_train_1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsClassifier

clf = Ridge(alpha=0.1,fit_intercept=True, normalize=False, copy_X=True, max_iter=None, tol=0.001, solver='cholesky', random_state=None)
clfe = ElasticNet(alpha=1.0, l1_ratio=0.5, fit_intercept=True, normalize=False, precompute=False, max_iter=1000, copy_X=True, tol=0.0001, warm_start=False, positive=False, random_state=None, selection='cyclic')
neigh = KNeighborsClassifier(n_neighbors=3)
reg=LinearRegression.fit(x_train_x_train, y_train_x_train)
reg1 = neigh.fit(x_train_x_train_1, y_train_x_train_1)
reg2 = neigh.fit(x_train_x_train_2, y_train_x_train_2)
reg10=ExtraTreesRegressor().fit(x_train_1, y_train_1)
reg20=ExtraTreesRegressor().fit(x_train_2, y_train_2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-653d92ec23d0> in <module>()
#      12 clfe = ElasticNet(alpha=1.0, l1_ratio=0.5, fit_intercept=True, normalize=False, precompute=False, max_iter=1000, copy_X=True, tol=0.0001, warm_start=False, positive=False, random_state=None, selection='cyclic')
#      13 neigh = KNeighborsClassifier(n_neighbors=3)
# ---> 14 reg=LinearRegression.fit(x_train_x_train, y_train_x_train)
#      15 reg1 = neigh.fit(x_train_x_train_1, y_train_x_train_1)
#      16 reg2 = neigh.fit(x_train_x_train_2, y_train_x_train_2)
#
# TypeError: fit() missing 1 required positional argument: 'y'

# %%
reg.fit(x_train,y_train)

# %%
reg.score(x_train_x_train, y_train_x_train)

# %%
y_train_x_train_1.shape

# %%
reg1.score(x_train_x_train_1, y_train_x_train_1)
# Out:
# 0.012049720953830542

# %%
reg2.score(x_train_x_train_2, y_train_x_train_2)
# Out:
# 0.39015728056823945

# %%
reg1.fit(x_train_x_train_1, y_train_x_train_1)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
tmt1=x_test.temp_1.median()
x_test.temp_1=x_test.temp_1.fillna(tmt1)
tmt2=x_test.temp_2.median()
x_test.temp_2=x_test.temp_2.fillna(tmt2)
tmh1=x_test.humidity_1.median()
x_test.humidity_1=x_test.humidity_1.fillna(tmh1)
tmh2=x_test.humidity_2.median()
x_test.humidity_2=x_test.humidity_2.fillna(tmh2)
x_test_1=x_test.drop(['temp_2','humidity_2'],axis=1)
x_test_2=x_test.drop(['temp_1','humidity_1'],axis=1)

# %%
#y_test=reg.predict(x_test)
#y_pred_x_train=reg.predict(x_test_x_train)
y_pred_x_train_1=reg1.predict(x_test_x_train_1)
y_pred_x_train_2=reg2.predict(x_test_x_train_2)

# %%
y_pred_10=reg10.predict(x_test_1)
y_pred_20=reg20.predict(x_test_2)

# %%
reg.score(x_test, y_test)

# %%
reg.score(x_test_x_train, y_test_x_train)

# %%
reg1.score(x_test_x_train_1, y_test_x_train_1)
# Out:
# 0.07648401826484018

# %%
reg2.score(x_test_x_train_2, y_test_x_train_2)
# Out:
# 0.014840182648401826

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test_x_train, y_pred_x_train)
#print(y_test_x_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-ae4aebbea2ac> in <module>()
#       1 from sklearn import metrics
# ----> 2 metrics.mean_absolute_error(y_test_x_train, y_pred_x_train)
#       3 #print(y_test_x_train)
#
# NameError: name 'y_pred_x_train' is not defined

# %%
metrics.mean_absolute_error(y_test_x_train_2, y_pred_x_train_2)
# Out:
# 34.93835616438356

# %%
d0 = { 'consumption_1': y_pred_x_train_1, 'consumption_2': y_pred_x_train_2}
y_pred_0 = pd.DataFrame(data=d0)

# %%
dx = { 'consumption_1': y_pred_x_train[:,0], 'consumption_2': y_pred_x_train[:,1]}
y_pred_x = pd.DataFrame(data=dx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-a28b80d1b7bb> in <module>()
# ----> 1 dx = { 'consumption_1': y_pred_x_train[:,0], 'consumption_2': y_pred_x_train[:,1]}
#       2 y_pred_x = pd.DataFrame(data=dx)
#
# NameError: name 'y_pred_x_train' is not defined

# %%
metrics.mean_absolute_error(y_test_x_train, y_pred_0)
# Out:
# 24.764269406392696

# %%
id=list(range(8760,17496))
len(id)
y=y_test.reshape(8736,2)
c1_pred=y[:,0]
len(c1_pred)
c2_pred= y[:,1]
len(c2_pred)
d = {'ID': id, 'consumption_1': c1_pred, 'consumption_2': c2_pred}
y_pred = pd.DataFrame(data=d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-dafb9168a929> in <module>()
#       1 id=list(range(8760,17496))
#       2 len(id)
# ----> 3 y=y_test.reshape(8736,2)
#       4 c1_pred=y[:,0]
#       5 len(c1_pred)
#
# NameError: name 'y_test' is not defined

# %%
d00 = {'ID': id, 'consumption_1': y_pred_10, 'consumption_2': y_pred_20}
y_pred_120 = pd.DataFrame(data=d00)

# %%
y_pred_120.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8736 entries, 0 to 8735
# Data columns (total 3 columns):
# ID               8736 non-null int64
# consumption_1    8736 non-null float64
# consumption_2    8736 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 204.8 KB

# %%
y_pred_120.to_csv('y_pred_csv_file.csv',index=False)

# %%
print(x_test)
# Out:
#       temp_1  temp_2  mean_national_temp  humidity_1  humidity_2  \
# 0        6.5     7.1                 8.8        91.0        82.0
# 1        6.8     7.0                 8.7        89.0        87.0
# 2        6.8     6.3                 8.7        88.0        91.0
# 3        5.8     5.8                 8.6        90.0        93.0
# 4        5.0     5.6                 8.5        90.0        94.0
# 5        5.2     5.2                 8.4        90.0        94.0
# 6        4.8     5.2                 8.2        91.0        96.0
# 7        3.9     5.2                 8.1        90.0        96.0
# 8        3.9     6.5                 8.3        93.0        97.0
# 9        5.6    12.4                 8.7        88.0        70.0
# 10       8.2    15.9                 9.4        77.0        57.0
# 11      10.2    19.1                10.3        68.0        44.0
# 12      11.7    19.9                11.3        64.0        40.0
# ...

# %%
list(range(1,4))
# Out:
# [1, 2, 3]

# %%
print(x_test)
# Out:
#       temp_1  temp_2  mean_national_temp  humidity_1  humidity_2  \
# 0        6.5     7.1                 8.8        91.0        82.0
# 1        6.8     7.0                 8.7        89.0        87.0
# 2        6.8     6.3                 8.7        88.0        91.0
# 3        5.8     5.8                 8.6        90.0        93.0
# 4        5.0     5.6                 8.5        90.0        94.0
# 5        5.2     5.2                 8.4        90.0        94.0
# 6        4.8     5.2                 8.2        91.0        96.0
# 7        3.9     5.2                 8.1        90.0        96.0
# 8        3.9     6.5                 8.3        93.0        97.0
# 9        5.6    12.4                 8.7        88.0        70.0
# 10       8.2    15.9                 9.4        77.0        57.0
# 11      10.2    19.1                10.3        68.0        44.0
# 12      11.7    19.9                11.3        64.0        40.0
# ...

# %%
def weighted_mean_absolute_error(dataframe_1, dataframe_2):
    """Weighted mean absolute error regression loss

        ----------
        y_true : array-like of shape = (n_samples,2)
        Ground truth (correct) target values.
        y_pred : array-like of shape = (n_samples,2)
        Estimated target values.

        """

    y_true = dataframe_1.values
    y_pred = dataframe_2.values
    c12 = np.array([1136987, 1364719])

    return 2 * metrics.mean_absolute_error(y_true*c12, y_pred*c12) / np.sum(c12)

# %%
weighted_mean_absolute_error(y_test_x_train, y_pred_0)
# Out:
# 25.69042344910226

# %%
weighted_mean_absolute_error(y_test_x_train, y_pred_x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-c15aeae93006> in <module>()
# ----> 1 weighted_mean_absolute_error(y_test_x_train, y_pred_x)
#
# NameError: name 'y_pred_x' is not defined
